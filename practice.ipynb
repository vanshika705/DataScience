# %%
import pandas as pd

# %%
dt={"NAME":["ankit","shalu","vanshu","shivi"],"BRANCH":["cse","ece","it","eee"]}
df1=pd.DataFrame(dt)
df1
# Out:
#      NAME BRANCH
# 0   ankit    cse
# 1   shalu    ece
# 2  vanshu     it
# 3   shivi    eee

# %%
dt2={"CITY":["ajmer","jaipur","beawar"],"AGE":[23,21,20]}
df2=pd.DataFrame(dt2)
df2
# Out:
#      CITY  AGE
# 0   ajmer   23
# 1  jaipur   21
# 2  beawar   20

# %%
combine=pd.concat([df1,df2],axis='columns')
combine
# Out:
#      NAME BRANCH    CITY   AGE
# 0   ankit    cse   ajmer  23.0
# 1   shalu    ece  jaipur  21.0
# 2  vanshu     it  beawar  20.0
# 3   shivi    eee     NaN   NaN

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1["NAME"]
# Out:
# 0     ankit
# 1     shalu
# 2    vanshu
# 3     shivi
# Name: NAME, dtype: object

# %%
type(df1["NAME"])
# Out:
# pandas.core.series.Series

# %%
df=pd.read_csv("Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail(3)
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.price
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df["city"]
# Out:
# 0        Ahmedabad
# 1            Delhi
# 2            Delhi
# 3        Bangalore
# 4        Bangalore
#            ...
# 32643        Delhi
# 32644       Karnal
# 32645        Delhi
# 32646       Jaipur
# 32647         Pune
# Name: city, Length: 32648, dtype: object

# %%
df[["price","city","age"]]
# Out:
#           price       city   age
# 0       35000.0  Ahmedabad   3.0
# 1      119900.0      Delhi   4.0
# 2      600000.0      Delhi   8.0
# 3       65000.0  Bangalore   4.0
# 4       80000.0  Bangalore   3.0
# ...         ...        ...   ...
# 32643   39000.0      Delhi   4.0
# 32644   30000.0     Karnal   9.0
# 32645   60000.0      Delhi   6.0
# 32646   15600.0     Jaipur  16.0
# 32647   22000.0       Pune  13.0
#
# [32648 rows x 3 columns]

# %%
df.loc[10:20,["price"]]
# Out:
#        price
# 10   72000.0
# 11   95000.0
# 12   78000.0
# 13   29499.0
# 14   29900.0
# 15   90000.0
# 16  120000.0
# 17   48000.0
# 18  240000.0
# 19   29900.0
# 20  120000.0

# %%
df.iloc[10:20,2:6]
# Out:
#          city  kms_driven         owner  age
# 10  Bangalore     20000.0   First Owner  7.0
# 11  Bangalore      9665.0   First Owner  4.0
# 12  Bangalore      9900.0   First Owner  4.0
# 13      Delhi     20000.0   First Owner  8.0
# 14      Delhi     20000.0   First Owner  7.0
# 15  Bangalore     11574.0   First Owner  3.0
# 16  Bangalore     23000.0   First Owner  3.0
# 17     Mumbai     24725.0   First Owner  5.0
# 18     Mumbai     15025.0  Second Owner  3.0
# 19      Delhi     20000.0   First Owner  7.0

# %%
df.price.std()
# Out:
# np.float64(90718.59520524176)

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.iloc[:5,:5]
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner
# 0  First Owner
# 1  First Owner
# 2  First Owner
# 3  First Owner
# 4  First Owner

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
under_50k=df[df["price"]<=50000]
under_50k
# Out:
#                                  bike_name    price         city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0        Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0        Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0        Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0       Mumbai     24725.0
# ...                                    ...      ...          ...         ...
# 32642                   Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643               Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner   age  power   brand
# ...

# %%
under_50k.price.max()
# Out:
# np.float64(50000.0)

# %%
under_50k.shape
# Out:
# (19114, 8)

# %%
under_50k.value_counts()
# Out:
# bike_name               price    city       kms_driven  owner         age   power  brand
# Honda CB Trigger 150cc  43000.0  Bangalore  42837.0     First Owner   8.0   150.0  Honda     620
# Yamaha FZ 150cc         45000.0  Chennai    18742.0     First Owner   6.0   150.0  Yamaha    620
# Yamaha Fazer 150cc      25000.0  Delhi      65000.0     First Owner   12.0  150.0  Yamaha    620
# Hero Passion 100cc      18000.0  Hyderabad  3869.0      First Owner   16.0  100.0  Hero      620
# Bajaj Pulsar 150cc      10000.0  Ghaziabad  64955.0     First Owner   15.0  150.0  Bajaj     620
#                                                                                             ...
# Yamaha YZF-R15 150cc    47000.0  Delhi      12643.0     Second Owner  9.0   150.0  Yamaha      1
# Bajaj  Pulsar 180cc     25000.0  Agra       22000.0     First Owner   13.0  180.0  Bajaj       1
#                         22800.0  Delhi      15000.0     Second Owner  10.0  180.0  Bajaj       1
# ...

# %%
under_50k["owner"].value_counts()
# Out:
# owner
# First Owner             17447
# Second Owner             1604
# Third Owner                57
# Fourth Owner Or More        6
# Name: count, dtype: int64

# %%
under_50k.price.value_counts()
# Out:
# price
# 25000.0    2071
# 35000.0    1446
# 18000.0    1356
# 32000.0    1350
# 30000.0     804
#            ...
# 29499.0       1
# 28100.0       1
# 24990.0       1
# 36995.0       1
# 11400.0       1
# Name: count, Length: 393, dtype: int64

# %%
ls=under_50k[under_50k.owner=="First Owner"]
ls
# Out:
#                                  bike_name    price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
# ...                                    ...      ...        ...         ...
# 32640               Hero Passion Pro 100cc  32000.0      Delhi     12000.0
# 32643               Hero Passion Pro 100cc  39000.0      Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0     Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0       Pune     60857.0
#
#              owner   age  power   brand
# ...

# %%
ls.price.min()
# Out:
# np.float64(4400.0)

# %%
ls.brand.value_counts()
# Out:
# brand
# Bajaj            6356
# Hero             5541
# Yamaha           2187
# Suzuki           1286
# Honda            1131
# TVS               905
# Mahindra           27
# Royal Enfield      13
# LML                 1
# Name: count, dtype: int64

# %%
under_50k.brand.unique()
# Out:
# array(['TVS', 'Hero', 'Bajaj', 'Suzuki', 'Yamaha', 'Honda', 'Mahindra',
#        'Royal Enfield', 'LML'], dtype=object)

# %%
under_50k.brand.nunique()
# Out:
# 9

# %%
ls2=df[(df.price<=100000) & (df.owner=="First Owner") & (df.age<=2)&(df.brand=="Bajaj")]
ls2
# Out:
#                              bike_name    price        city  kms_driven  \
# 95                  Bajaj Pulsar 150cc  60000.0        Pune      2000.0
# 340        Bajaj Pulsar 125cc Disc CBS  47000.0       Banki     14009.0
# 341           Bajaj Avenger Street 220  95000.0       Delhi     11000.0
# 510                 Bajaj Pulsar 150cc  66000.0       Delhi     15000.0
# 619           Bajaj V15 150cc POWER UP  35000.0      Mumbai     26000.0
# 889   Bajaj Pulsar 150cc Rear Disc ABS  85000.0    Balaghat      2500.0
# 1340         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1401                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1423                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1445         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1818             Bajaj CT 100 ES Alloy  39000.0   Faridabad      2564.0
# 1819     Bajaj Platina  Alloy ES-100cc  39000.0   Faridabad     12193.0
# ...

# %%
ls2.shape
# Out:
# (41, 8)

# %%
categorical=(df.select_dtypes(include="O"))
categorical
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...

# %%
numerical=(df.select_dtypes(exclude="O"))
numerical
# Out:
#           price  kms_driven   age  power
# 0       35000.0     17654.0   3.0  110.0
# 1      119900.0     11000.0   4.0  350.0
# 2      600000.0       110.0   8.0  675.0
# 3       65000.0     16329.0   4.0  180.0
# 4       80000.0     10000.0   3.0  150.0
# ...         ...         ...   ...    ...
# 32643   39000.0     22000.0   4.0  100.0
# 32644   30000.0      6639.0   9.0  180.0
# 32645   60000.0     20373.0   6.0  220.0
# 32646   15600.0     84186.0  16.0  125.0
# 32647   22000.0     60857.0  13.0  150.0
#
# [32648 rows x 4 columns]

# %%
df3=pd.concat([categorical,numerical],axis="columns")
df3
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand     price  kms_driven   age  power
# 0                TVS   35000.0     17654.0   3.0  110.0
# ...

# %%
df["dummy"]="hello"
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
ktm=df[df.brand=="KTM"]
ktm
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand  dummy
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df3.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df3[df3.duplicated()]
# Out:
#                              bike_name       city        owner          brand  \
# 19                 Bajaj Discover 125M      Delhi  First Owner          Bajaj
# 20              Bajaj Pulsar RS200 ABS  Bangalore  First Owner          Bajaj
# 21              Suzuki Gixxer SF 150cc     Mumbai  First Owner         Suzuki
# 25                  Bajaj Pulsar NS200  Bangalore  First Owner          Bajaj
# 90     Royal Enfield Thunderbird 350cc     Mumbai  First Owner  Royal Enfield
# ...                                ...        ...          ...            ...
# 32643           Hero Passion Pro 100cc      Delhi  First Owner           Hero
# 32644             TVS Apache RTR 180cc     Karnal  First Owner            TVS
# 32645         Bajaj Avenger Street 220      Delhi  First Owner          Bajaj
# 32646        Hero Super Splendor 125cc     Jaipur  First Owner           Hero
# 32647               Bajaj Pulsar 150cc       Pune  First Owner          Bajaj
#
# ...

# %%
df3.drop_duplicates()
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand     price  kms_driven  age  power
# 0                 TVS   35000.0     17654.0  3.0  110.0
# ...

# %%
df["brand"].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
df4=df[(df["brand"]=="KTM")|(df["brand"]=="Suzuki")|(df["brand"]=="Jawa")]
df4
# Out:
#                          bike_name     price       city  kms_driven  \
# 17          Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 21          Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 33                    KTM RC 390cc  180000.0       Pune     17700.0
# 35                  KTM Duke 200cc   70000.0     Nashik    100000.0
# 39                KTM RC 200cc ABS  179000.0  Bangalore      3400.0
# ...                            ...       ...        ...         ...
# 32597            Suzuki Zeus 125cc   35000.0  Ahmedabad     11885.0
# 32598                 KTM RC 390cc  196700.0     Mumbai     13216.0
# 32630  Suzuki Slingshot Plus 125cc   32000.0    Lucknow     22697.0
# 32635            Suzuki Zeus 125cc   35000.0  Ahmedabad     11885.0
# 32636                 KTM RC 390cc  196700.0     Mumbai     13216.0
#
#               owner   age  power   brand  dummy
# 17      First Owner   5.0  150.0  Suzuki  hello
# 21      First Owner   5.0  150.0  Suzuki  hello
# ...

# %%
brand_ls=["KTM","Suzuki","Jawa"]
filter_df=df[df["brand"].isin(brand_ls)]
filter_df
# Out:
#                          bike_name     price       city  kms_driven  \
# 17          Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 21          Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 33                    KTM RC 390cc  180000.0       Pune     17700.0
# 35                  KTM Duke 200cc   70000.0     Nashik    100000.0
# 39                KTM RC 200cc ABS  179000.0  Bangalore      3400.0
# ...                            ...       ...        ...         ...
# 32597            Suzuki Zeus 125cc   35000.0  Ahmedabad     11885.0
# 32598                 KTM RC 390cc  196700.0     Mumbai     13216.0
# 32630  Suzuki Slingshot Plus 125cc   32000.0    Lucknow     22697.0
# 32635            Suzuki Zeus 125cc   35000.0  Ahmedabad     11885.0
# 32636                 KTM RC 390cc  196700.0     Mumbai     13216.0
#
#               owner   age  power   brand  dummy
# 17      First Owner   5.0  150.0  Suzuki  hello
# 21      First Owner   5.0  150.0  Suzuki  hello
# ...

# %%
city_name=["Mumbai","Pune","Nashik","Jaipur"]
filter_city=df[df["city"].isin(city_name)]
filter_city
# Out:
#                              bike_name     price    city  kms_driven  \
# 17              Suzuki Gixxer SF 150cc   48000.0  Mumbai     24725.0
# 18                  Benelli 302R 300CC  240000.0  Mumbai     15025.0
# 21              Suzuki Gixxer SF 150cc   48000.0  Mumbai     24725.0
# 33                        KTM RC 390cc  180000.0    Pune     17700.0
# 35                      KTM Duke 200cc   70000.0  Nashik    100000.0
# ...                                ...       ...     ...         ...
# 32620         Honda CB Hornet 160R STD   87000.0    Pune       140.0
# 32634  Royal Enfield Thunderbird 350cc   70000.0  Mumbai     13858.0
# 32636                     KTM RC 390cc  196700.0  Mumbai     13216.0
# 32646        Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32647               Bajaj Pulsar 150cc   22000.0    Pune     60857.0
#
#               owner   age  power          brand  dummy
# 17      First Owner   5.0  150.0         Suzuki  hello
# ...

# %%
filter_city["city"].value_counts()
# Out:
# city
# Mumbai    2591
# Pune      1724
# Jaipur    1007
# Nashik      13
# Name: count, dtype: int64

# %%
jaipur=df[df["city"]=="Jaipur"]
jaipur
# Out:
#                          bike_name     price    city  kms_driven  \
# 47      Mahindra Centuro NXT 110cc   28000.0  Jaipur     45000.0
# 134         Suzuki Gixxer SF 150cc   47000.0  Jaipur     70000.0
# 166    Royal Enfield Classic 350cc  123600.0  Jaipur      7702.0
# 189       Harley-Davidson Iron 883  435000.0  Jaipur      5550.0
# 490           Honda CBR 150R 150cc   55000.0  Jaipur      2000.0
# ...                            ...       ...     ...         ...
# 32551    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32570    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32589    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32608    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32646    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
#
#               owner   age  power            brand  dummy
# 47      First Owner   2.0  110.0         Mahindra  hello
# 134     First Owner   6.0  150.0           Suzuki  hello
# ...

# %%
jaipur_ktm=jaipur["brand"]=="KTM"
jaipur_ktm.value_counts()
# Out:
# brand
# False    999
# True       8
# Name: count, dtype: int64

# %%
brand_ls2=["KTM","TVS","Suzuki"]
jaipur_bikes=jaipur[jaipur["brand"].isin(brand_ls2)]
jaipur_bikes
# Out:
#                                bike_name      price    city  kms_driven  \
# 134               Suzuki Gixxer SF 150cc    47000.0  Jaipur     70000.0
# 617               Suzuki Hayabusa 1300cc  1260000.0  Jaipur     17000.0
# 888                         KTM RC 390cc   147000.0  Jaipur     15000.0
# 1132  TVS Apache RTR 160 4V DISC ABS BS6    98000.0  Jaipur       749.0
# 1304                TVS Apache RTR 160cc    63000.0  Jaipur      1639.0
# 2070                    TVS Apache RR310   185000.0  Jaipur      2845.0
# 2302                TVS Apache RTR 160cc    19542.0  Jaipur     56592.0
# 2395                TVS Apache RTR 160cc    19542.0  Jaipur     56592.0
# 3364            TVS Star City Plus 110cc    30000.0  Jaipur     27000.0
# 3904                TVS Apache RTR 160cc    51000.0  Jaipur     18314.0
# 3907                TVS Apache RTR 160cc    47000.0  Jaipur     26000.0
# 3920                 TVS Star City 110cc    26500.0  Jaipur      2342.0
# ...

# %%
under_70k=jaipur_bikes[jaipur_bikes["price"]<70000]
under_70k
# Out:
#                      bike_name    price    city  kms_driven         owner  \
# 134     Suzuki Gixxer SF 150cc  47000.0  Jaipur     70000.0   First Owner
# 1304      TVS Apache RTR 160cc  63000.0  Jaipur      1639.0   First Owner
# 2302      TVS Apache RTR 160cc  19542.0  Jaipur     56592.0   First Owner
# 2395      TVS Apache RTR 160cc  19542.0  Jaipur     56592.0   First Owner
# 3364  TVS Star City Plus 110cc  30000.0  Jaipur     27000.0   First Owner
# 3904      TVS Apache RTR 160cc  51000.0  Jaipur     18314.0   First Owner
# 3907      TVS Apache RTR 160cc  47000.0  Jaipur     26000.0   First Owner
# 3920       TVS Star City 110cc  26500.0  Jaipur      2342.0   First Owner
# 3922       TVS Star City 110cc  26000.0  Jaipur     24000.0   First Owner
# 4063           TVS Sport 100cc  33000.0  Jaipur     18677.0   First Owner
# 4181      TVS Apache RTR 160cc  51000.0  Jaipur     18314.0   First Owner
# 4371      TVS Apache RTR 160cc  68000.0  Jaipur     11123.0   First Owner
# ...

# %%
under_70k.shape
# Out:
# (37, 9)

# %%
under_70k[(under_70k["owner"]=="First Owner")|(under_70k["age"]<=2)|(under_70k["power"]==180)]
# Out:
#                      bike_name    price    city  kms_driven        owner  \
# 134     Suzuki Gixxer SF 150cc  47000.0  Jaipur     70000.0  First Owner
# 1304      TVS Apache RTR 160cc  63000.0  Jaipur      1639.0  First Owner
# 2302      TVS Apache RTR 160cc  19542.0  Jaipur     56592.0  First Owner
# 2395      TVS Apache RTR 160cc  19542.0  Jaipur     56592.0  First Owner
# 3364  TVS Star City Plus 110cc  30000.0  Jaipur     27000.0  First Owner
# 3904      TVS Apache RTR 160cc  51000.0  Jaipur     18314.0  First Owner
# 3907      TVS Apache RTR 160cc  47000.0  Jaipur     26000.0  First Owner
# 3920       TVS Star City 110cc  26500.0  Jaipur      2342.0  First Owner
# 3922       TVS Star City 110cc  26000.0  Jaipur     24000.0  First Owner
# 4063           TVS Sport 100cc  33000.0  Jaipur     18677.0  First Owner
# 4181      TVS Apache RTR 160cc  51000.0  Jaipur     18314.0  First Owner
# 4371      TVS Apache RTR 160cc  68000.0  Jaipur     11123.0  First Owner
# ...

# %%
jaipur.sort_values("price")
# Out:
#                            bike_name      price    city  kms_driven  \
# 9029              Hero Passion 100cc    14000.0  Jaipur     50000.0
# 3654         Hero Passion Plus 100cc    14000.0  Jaipur     70756.0
# 2696         Hero Passion Plus 100cc    14000.0  Jaipur     70756.0
# 3113              Bajaj CT 100 100cc    15000.0  Jaipur     48000.0
# 2983              Bajaj CT 100 100cc    15000.0  Jaipur     48000.0
# ...                              ...        ...     ...         ...
# 2599      Harley-Davidson Street 750   445600.0  Jaipur      1500.0
# 3826      Harley-Davidson Street 750   445600.0  Jaipur      1500.0
# 7650                   Kawasaki Z650   478000.0  Jaipur      1234.0
# 9187  Harley-Davidson Street 750 ABS   520000.0  Jaipur       399.0
# 617           Suzuki Hayabusa 1300cc  1260000.0  Jaipur     17000.0
#
#              owner   age   power            brand  dummy
# 9029  Second Owner  19.0   100.0             Hero  hello
# ...

# %%
delhi=df[df["city"]=="Delhi"]
delhi
# Out:
#                                  bike_name     price   city  kms_driven  \
# 1              Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# ...                                    ...       ...    ...         ...
# 32639          Royal Enfield Classic 350cc   95500.0  Delhi     18000.0
# 32640               Hero Passion Pro 100cc   32000.0  Delhi     12000.0
# 32641                  Bajaj Avenger 220cc   41000.0  Delhi     20245.0
# 32643               Hero Passion Pro 100cc   39000.0  Delhi     22000.0
# 32645             Bajaj Avenger Street 220   60000.0  Delhi     20373.0
#
#               owner   age  power          brand  dummy
# ...

# %%
top_10=delhi.sort_values("price",ascending=False).head(10)
top_10
# Out:
#                            bike_name      price   city  kms_driven  \
# 4864               BMW S 1000 RR Pro  1800000.0  Delhi      2600.0
# 7671            Yamaha YZF-R1 1000cc  1550000.0  Delhi      9800.0
# 3016               BMW S 1000 XR Pro  1500000.0  Delhi     18000.0
# 6501  Ducati Multistrada 1200 Enduro  1490000.0  Delhi     12500.0
# 6070               BMW F750 GS 850cc  1350000.0  Delhi      4600.0
# 6549               BMW F750 GS 850cc  1350000.0  Delhi      4600.0
# 7481          Suzuki Hayabusa 1300cc  1149000.0  Delhi      9875.0
# 7064  Harley-Davidson Fat Bob 107 Ci  1100000.0  Delhi     24000.0
# 7638             Ducati Panigale 959  1070500.0  Delhi       289.0
# 7595             Ducati Panigale 959  1070500.0  Delhi       289.0
#
#              owner  age   power            brand  dummy
# 4864   First Owner  4.0  1000.0              BMW  hello
# 7671  Second Owner  6.0  1000.0           Yamaha  hello
# 3016   First Owner  4.0  1000.0              BMW  hello
# ...

# %%
top_10.brand.value_counts()
# Out:
# brand
# BMW                4
# Ducati             3
# Yamaha             1
# Suzuki             1
# Harley-Davidson    1
# Name: count, dtype: int64

# %%
top_10.to_csv("delhi_top_10",index=False)

# %%
df.drop("dummy",axis="columns",inplace=True)

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
import numpy as np

# %%
dt=t = {"A":[1,2,4,np.nan,5],
      "B":[7,4,np.nan,9,2],
      "C":[np.nan,8,7,5,6],
      "D":[7,4,1,2,5]}
dt
# Out:
# {'A': [1, 2, 4, nan, 5],
#  'B': [7, 4, nan, 9, 2],
#  'C': [nan, 8, 7, 5, 6],
#  'D': [7, 4, 1, 2, 5]}

# %%
df=pd.DataFrame(dt)
df
# Out:
#      A    B    C  D
# 0  1.0  7.0  NaN  7
# 1  2.0  4.0  8.0  4
# 2  4.0  NaN  7.0  1
# 3  NaN  9.0  5.0  2
# 4  5.0  2.0  6.0  5

# %%
df.isnull().sum()
# Out:
# A    1
# B    1
# C    1
# D    0
# dtype: int64

# %%
df.dropna(axis=1)
# Out:
#    D
# 0  7
# 1  4
# 2  1
# 3  2
# 4  5

# %%
df["A"].fillna(1000)
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 3    1000.0
# 4       5.0
# Name: A, dtype: float64

# %%
df.fillna(1000)
# Out:
#         A       B       C  D
# 0     1.0     7.0  1000.0  7
# 1     2.0     4.0     8.0  4
# 2     4.0  1000.0     7.0  1
# 3  1000.0     9.0     5.0  2
# 4     5.0     2.0     6.0  5

# %%
df.B.mean()
# Out:
# np.float64(5.5)

# %%
df.B.median()
# Out:
# np.float64(5.5)

# %%
df.B.fillna(5.5)
# Out:
# 0    7.0
# 1    4.0
# 2    5.5
# 3    9.0
# 4    2.0
# Name: B, dtype: float64

# %%
df.C.mean()
# Out:
# np.float64(6.5)

# %%
df.C.median()
# Out:
# np.float64(6.5)

# %%
df.C.fillna(6.5)
# Out:
# 0    6.5
# 1    8.0
# 2    7.0
# 3    5.0
# 4    6.0
# Name: C, dtype: float64

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  7.0  NaN  7
# 1  2.0  4.0  8.0  4
# 2  4.0  NaN  7.0  1
# 3  NaN  9.0  5.0  2
# 4  5.0  2.0  6.0  5

# %%
df=pd.read_csv("Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
df.brand.value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
group=df.groupby("brand")
group

# %%
group[["price"]].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
group2=group["price"].agg(min_price="min",max_price="max",mean_price="mean")
group2
# Out:
#                  min_price  max_price    mean_price
# brand
# BMW               255000.0  1800000.0  6.735000e+05
# Bajaj               6400.0   195000.0  4.903128e+04
# Benelli           110700.0   785000.0  2.983761e+05
# Ducati            380000.0  1500000.0  9.005750e+05
# Harley-Davidson   250000.0  1100000.0  4.734291e+05
# Hero                5000.0   104000.0  3.068307e+04
# Honda              10000.0   800000.0  5.147068e+04
# Hyosung           120000.0   493500.0  2.432084e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.884286e+05
# KTM                55000.0   860000.0  1.479469e+05
# Kawasaki          110000.0  1100000.0  4.167116e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.266667e+06
# Mahindra           17800.0   175000.0  7.005780e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
# find the min price brand with name or price 
group.price.min()
# Out:
# brand
# BMW                255000.0
# Bajaj                6400.0
# Benelli            110700.0
# Ducati             380000.0
# Harley-Davidson    250000.0
# Hero                 5000.0
# Honda               10000.0
# Hyosung            120000.0
# Ideal              100000.0
# Indian             700000.0
# Jawa               146000.0
# KTM                 55000.0
# Kawasaki           110000.0
# LML                  4400.0
# MV                 950000.0
# Mahindra            17800.0
# Rajdoot             75000.0
# Royal Enfield       33500.0
# Suzuki               8000.0
# TVS                  5800.0
# Triumph            500000.0
# Yamaha               9400.0
# Yezdi               68000.0
# Name: price, dtype: float64

# %%
df["brands"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brands'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 df["brands"].value_counts()
#
# ...
